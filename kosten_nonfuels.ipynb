# %% [markdown]
# <a href="https://colab.research.google.com/github/MarCam60/Assignment-Income-inequality-in-relation-to-GDP/blob/main/kosten_nonfuels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_cost = pd.read_excel('/content/kosten nonfuels.xlsx')
df_cost
# Out:
#    Global weighted average cost of electricity (2019 USD/kWh)  \
# 0                                                Year
# 1                                                2010
# 2                                                2011
# 3                                                2012
# 4                                                2013
# 5                                                2014
# 6                                                2015
# 7                                                2016
# 8                                                2017
# 9                                                2018
# 10                                               2019
# 11                                               2020
# 12                                               2021
# 13                                               2022
# 14                                               2023
#
#                    Unnamed: 1     Unnamed: 2    Unnamed: 3          Unnamed: 4
# ...
